# %% [markdown]
# # daewoo_module.py

# %%
import pandas as pd
import os
import tensorflow as tf
from daewoo_module import *
import sklearn.metrics as skm
import time
from collections import Counter
# Out:
# C:\Users\Jay\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
NUM_CLASSES = 3

# %%
def set_input(img, label):
    np.random.seed(1234)
    idx = np.random.permutation(len(img))
    tr_idx = idx[:round(0.8 * len(idx))]
    ts_idx = idx[round(0.8 * len(idx)):]

    train_img = img[tr_idx]
    train_label = label[tr_idx]
    test_img = img[ts_idx]
    test_label = label[ts_idx]

    train_img_tensor = tf.constant(train_img)
    train_label_tensor = tf.constant(train_label)
    test_img_tensor = tf.constant(test_img)
    test_label_tensor = tf.constant(test_label)

    return train_img_tensor, train_label_tensor, test_img_tensor, test_label_tensor, tr_idx, ts_idx

# %%
# string 텐서를 img 텐서로 변환 후 crop
def input_tensor(img_path, label):
    label_crop = tf.one_hot(label, NUM_CLASSES)
    
    img_file = tf.read_file(img_path)
    img_decoded = tf.image.decode_png(img_file)
    img_crop = tf.image.crop_to_bounding_box(img_decoded, 135, 0, 135, 135)
    img_float = tf.to_float(img_crop)
    img_crop = tf.random_crop(img_float, size=[135, 135, 3])
    
    for i in range(1,10):
        _label = tf.one_hot(label, NUM_CLASSES)
        
        _img_crop = tf.image.crop_to_bounding_box(img_decoded, 135, 38*i, 135, 135)
        _img_float = tf.to_float(_img_crop)
        _img_crop = tf.random_crop(_img_float, size=[135, 135, 3])
        
        label_crop = tf.concat([label_crop, _label], axis=0)
        img_crop = tf.concat([img_crop, _img_crop], axis=0)

    return tf.reshape(img_crop, [-1,135,135,3]), tf.reshape(label_crop, [-1,3])

# %%
def make_batch(dataset):
    dataset_0 = dataset.filter(lambda x,y: tf.reshape(tf.equal(tf.argmax(y), tf.argmax(tf.constant([1,0,0], tf.float32))), []))
    dataset_1 = dataset.filter(lambda x,y: tf.reshape(tf.equal(tf.argmax(y), tf.argmax(tf.constant([0,1,0], tf.float32))), [])).repeat()
    dataset_2 = dataset.filter(lambda x,y: tf.reshape(tf.equal(tf.argmax(y), tf.argmax(tf.constant([0,0,1], tf.float32))), [])).repeat()
    
    datasets = tf.data.Dataset.zip((dataset_0, dataset_1, dataset_2))
    datasets = datasets.flat_map(lambda ex_0, ex_1, ex_2: tf.data.Dataset.from_tensors(ex_0).concatenate(tf.data.Dataset.from_tensors(ex_1))
                                 .concatenate(tf.data.Dataset.from_tensors(ex_2)))
    
    return datasets

# %%
def conv2d(x, num_outputs, batch_norm=True):
    if batch_norm is True:
        conv_bn = tf.contrib.layers.batch_norm
    else:
        conv_bn = None

    conv = tf.contrib.layers.conv2d(inputs=x,
                                    num_outputs=num_outputs,
                                    kernel_size=(3, 3),
                                    normalizer_fn=conv_bn,
                                    activation_fn=tf.nn.relu)
    return conv

# %%
def pooling(x):
    pool = tf.contrib.layers.max_pool2d(inputs=x, kernel_size=(2, 2))
    return pool

# %%
def dense(x, output, fn=tf.nn.relu, batch_norm=True):
    if batch_norm is True:
        fc_bn = tf.contrib.layers.batch_norm
    else:
        fc_bn = None
    fc = tf.contrib.layers.fully_connected(inputs=x,
                                           num_outputs=output,
                                           normalizer_fn=fc_bn,
                                           activation_fn=fn)
    return fc

# %%
class VGG16():
    def __init__(self, x, y, bn, classification):
        
        with tf.name_scope("input"):
            self.x = x
            self.y = y

        with tf.name_scope("layer_1"):
            conv1 = conv2d(x, 64, batch_norm=bn)
            conv2 = conv2d(conv1, 64, batch_norm=bn)
            pool1 = pooling(conv2)

        with tf.name_scope("layer_2"):
            conv3 = conv2d(pool1, 128, batch_norm=bn)
            conv4 = conv2d(conv3, 128, batch_norm=bn)
            pool2 = pooling(conv4)

        with tf.name_scope("layer_3"):
            conv5 = conv2d(pool2, 256, batch_norm=bn)
            conv6 = conv2d(conv5, 256, batch_norm=bn)
            conv7 = conv2d(conv6, 256, batch_norm=bn)
            pool3 = pooling(conv7)

        with tf.name_scope("layer_4"):
            conv8 = conv2d(pool3, 512, batch_norm=bn)
            conv9 = conv2d(conv8, 512, batch_norm=bn)
            conv10 = conv2d(conv9, 512, batch_norm=bn)
            pool4 = pooling(conv10)

        with tf.name_scope("layer_5"):
            conv11 = conv2d(pool4, 512, batch_norm=bn)
            conv12 = conv2d(conv11, 512, batch_norm=bn)
            conv13 = conv2d(conv12, 512, batch_norm=bn)
            pool5 = pooling(conv13)

        with tf.name_scope("FC_layer"):
            fc1 = tf.layers.flatten(pool5)
            fc2 = dense(fc1, 4096, batch_norm=bn)
            fc3 = dense(fc2, 4096, batch_norm=bn)

        self.learning_rate = tf.placeholder(tf.float32)
        self.global_step = tf.Variable(0, trainable=False, name='global_step')

        if classification is True:
            self.logits = dense(fc3, NUM_CLASSES, fn=None, batch_norm=True)
            self.loss = tf.losses.softmax_cross_entropy(onehot_labels=self.y, logits=self.logits)
            self.lr_decay = tf.train.exponential_decay(self.learning_rate, self.global_step, 1000, 0.9, staircase=True)
            self.extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
            
            with tf.control_dependencies(self.extra_update_ops):
                self.adam = tf.train.AdamOptimizer(self.lr_decay).minimize(self.loss,
                                                                           global_step=self.global_step)
                self.sgd = tf.train.GradientDescentOptimizer(self.lr_decay).minimize(self.loss,
                                                                                     global_step=self.global_step)
                self.rms = tf.train.RMSPropOptimizer(self.lr_decay).minimize(self.loss,
                                                                             global_step=self.global_step)
                self.momentum = tf.train.MomentumOptimizer(self.lr_decay, momentum=0.9).minimize(self.loss,
                                                                                                 global_step=self.global_step)

            self.y_prob = tf.nn.softmax(self.logits)
            self.y_pred = tf.argmax(self.y_prob, 1)

            self.correct_prediction = tf.equal(self.y_pred, tf.arg_max(y, 1))
            self.accuracy = tf.reduce_mean(tf.cast(self.correct_prediction, tf.float32))

            tf.summary.scalar("accuray", self.accuracy)
            tf.summary.scalar("loss", self.loss)

        else:
            self.logits = tf.layers.dense(fc3, 1, activation=tf.nn.relu)
            self.loss = tf.losses.mean_squared_error(labels=self.y, predictions=self.logits)
            self.lr_decay = tf.train.exponential_decay(self.learning_rate, self.global_step, 1000, 0.9, staircase=True)
            self.extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
            
            with tf.control_dependencies(self.extra_update_ops):
                self.adam = tf.train.AdamOptimizer(self.lr_decay).minimize(self.loss,
                                                                           global_step=self.global_step)
                self.sgd = tf.train.GradientDescentOptimizer(self.lr_decay).minimize(self.loss,
                                                                                     global_step=self.global_step)
                self.rms = tf.train.RMSPropOptimizer(self.lr_decay).minimize(self.loss,
                                                                             global_step=self.global_step)
                self.momentum = tf.train.MomentumOptimizer(self.lr_decay, momentum=0.9).minimize(self.loss,
                                                                                                 global_step=self.global_step)
            
            tf.summary.scalar("loss", self.loss)

        self.merged_summary_op = tf.summary.merge_all()

# %% [markdown]
# # daewoo_train_original.py

# %%
os.environ['FOR_DISABLE_CONSOLE_CTRL_HANDLER'] = '1'

# %%
root_dir = "./input_data"
img_dir = "./input_data/figure/"
logs_path = os.path.join(root_dir, "graph")

# %%
img = np.array([img_dir + x for x in os.listdir(img_dir)])
label = pd.read_csv(os.path.join(root_dir, 'description.csv'), engine='python')

# %%
classification = True

batch_size = 64
epochs = 2

# %%
if classification is True:
    label = pd.cut(label['WVHT ft.y'], bins=[0, 5.2, 7.9, 100], labels=[0, 1, 2], include_lowest=True)
    label = np.array(label)
else:
    label = label['WVHT ft.y'].values
    label = ((label - np.mean(label)) / np.std(label)).reshape(-1, 1)

# %%
train_img_tensor, train_label_tensor, test_img_tensor, test_label_tensor, tr_idx, ts_idx = set_input(img, label)

# %%
train_imgs = tf.data.Dataset.from_tensor_slices((train_img_tensor, train_label_tensor))
test_imgs = tf.data.Dataset.from_tensor_slices((test_img_tensor, test_label_tensor))
infer_imgs = tf.data.Dataset.from_tensor_slices((test_img_tensor, test_label_tensor))

# %%
if classification is True:
    train_imgs = train_imgs.map(input_tensor).apply(tf.contrib.data.unbatch()).shuffle(buffer_size=100).apply(lambda x: make_batch(x)).batch(batch_size).repeat()
    test_imgs = test_imgs.map(input_tensor).apply(tf.contrib.data.unbatch()).shuffle(buffer_size=100).apply(lambda x: make_batch(x)).batch(batch_size).repeat()
    infer_imgs = infer_imgs.map(input_tensor).apply(tf.contrib.data.unbatch()).batch(batch_size)
else:
    train_imgs = train_imgs.map(input_tensor_regression).apply(tf.contrib.data.unbatch()).shuffle(buffer_size=100).apply(lambda x: make_batch(x)).batch(batch_size).repeat()
    test_imgs = test_imgs.map(input_tensor_regression).apply(tf.contrib.data.unbatch()).shuffle(buffer_size=100).apply(lambda x: make_batch(x)).batch(batch_size).repeat()
    infer_imgs = infer_imgs.map(input_tensor).apply(tf.contrib.data.unbatch()).batch(batch_size)

# %%
train_iterator = train_imgs.make_initializable_iterator()
test_iterator = test_imgs.make_initializable_iterator()
infer_iterator = infer_imgs.make_initializable_iterator()
handle = tf.placeholder(tf.string, shape=[])

# %%
iterator = tf.data.Iterator.from_string_handle(handle, train_imgs.output_types, train_imgs.output_shapes)
x, y = iterator.get_next()

# %%
# train class: [18204, 17525, 15748]
train_batches = 18204*3*10 // batch_size

# %%
model = VGG16(x, y, bn=True, classification=classification)
# Out:
# WARNING:tensorflow:From C:\Users\Jay\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\losses\losses_impl.py:691: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From <ipython-input-9-7b32c19851a2>:63: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead

# %%
if classification is True:
    model_name = "vgg16_classification_crop10"
else:
    model_name = "vgg16_regression_crop10"

# %%
start_time = time.time()

config = tf.ConfigProto()
config.gpu_options.allow_growth = True

# %%
sess = tf.Session(config=config)
saver = tf.train.Saver()
sess.run(tf.global_variables_initializer())
train_handle = sess.run(train_iterator.string_handle())
test_handle = sess.run(test_iterator.string_handle())
infer_handle = sess.run(infer_iterator.string_handle())
train_writer = tf.summary.FileWriter(os.path.join(logs_path, model_name, 'train'), sess.graph)
test_writer = tf.summary.FileWriter(os.path.join(logs_path, model_name, 'test'))

# %%
LEARNING_RATE = 0.001
optimizer = model.rms

# %%
if classification is True:

    print("Training!")
    for i in range(epochs):
        print("-------{} Epoch--------".format(i + 1))
        sess.run(train_iterator.initializer)
        sess.run(test_iterator.initializer)
        for j in range(train_batches):
            summary, _, acc, loss_ = sess.run([model.merged_summary_op, optimizer, model.accuracy, model.loss],
                                              feed_dict={handle: train_handle, model.learning_rate: LEARNING_RATE})
            step = tf.train.global_step(sess, model.global_step)
            print("Training Iter : {}, Acc : {}, Loss : {:.4f}".format(step, acc, loss_))

            if j % 10 == 0:
                train_writer.add_summary(summary, step)
                summary, acc, loss_ = sess.run([model.merged_summary_op, model.accuracy, model.loss],
                                               feed_dict={handle: test_handle})
                print("Validation Iter : {}, Acc : {}, Loss : {:.4f}".format(step, acc, loss_))
                test_writer.add_summary(summary, step)

    print("-----------End of training-------------")

    end_time = time.time() - start_time
    print("{} seconds".format(end_time))

    saver.save(sess, os.path.join(logs_path, 'VGG16_classification_crop', model_name))

else:
    print("Training!")
    for i in range(epochs):
        print("-------{} Epoch--------".format(i + 1))
        sess.run(train_iterator.initializer)
        sess.run(test_iterator.initializer)
        for j in range(train_batches):
            summary, _, loss_ = sess.run([model.merged_summary_op, optimizer, model.loss],
                                         feed_dict={handle: train_handle, model.learning_rate: LEARNING_RATE})
            step = tf.train.global_step(sess, model.global_step)
            print("Training Iter : {}, Loss : {:.4f}".format(step, loss_))

            if j % 10 == 0:
                train_writer.add_summary(summary, step)
                summary, loss_ = sess.run([model.merged_summary_op, model.loss],
                                          feed_dict={handle: test_handle})
                print("Validation Iter : {}, Loss : {:.4f}".format(step, loss_))
                test_writer.add_summary(summary, step)

    print("-----------End of training-------------")

    end_time = time.time() - start_time
    print("{} seconds".format(end_time))

    saver.save(sess, os.path.join(logs_path, 'VGG16_regression_crop', model_name))
# Out:
# Training!
# -------1 Epoch--------
# Training Iter : 1, Acc : 0.265625, Loss : 1.3475
# Validation Iter : 1, Acc : 0.34375, Loss : 1.4018
# Training Iter : 2, Acc : 0.5, Loss : 1.0482
# Training Iter : 3, Acc : 0.46875, Loss : 1.2122
# Training Iter : 4, Acc : 0.5, Loss : 0.9832
# Training Iter : 5, Acc : 0.59375, Loss : 1.0180
# Training Iter : 6, Acc : 0.421875, Loss : 1.1789
# Training Iter : 7, Acc : 0.40625, Loss : 1.0916
# Training Iter : 8, Acc : 0.515625, Loss : 1.0083
# Training Iter : 9, Acc : 0.359375, Loss : 1.4293
# Training Iter : 380, Acc : 0.34375, Loss : 1.0965
# Training Iter : 381, Acc : 0.328125, Loss : 1.0986
# Validation Iter : 381, Acc : 0.359375, Loss : 1.0969
# Training Iter : 382, Acc : 0.25, Loss : 1.1084
# Training Iter : 383, Acc : 0.28125, Loss : 1.1026
# Training Iter : 384, Acc : 0.234375, Loss : 1.0999
# Training Iter : 385, Acc : 0.28125, Loss : 1.0969
# Training Iter : 386, Acc : 0.328125, Loss : 1.0941
# Training Iter : 387, Acc : 0.421875, Loss : 1.0943
# Training Iter : 388, Acc : 0.28125, Loss : 1.0965
# Training Iter : 389, Acc : 0.34375, Loss : 1.0975
# Training Iter : 390, Acc : 0.375, Loss : 1.0948
# Training Iter : 391, Acc : 0.3125, Loss : 1.1039
# Validation Iter : 391, Acc : 0.328125, Loss : 1.0982
# Training Iter : 392, Acc : 0.3125, Loss : 1.0975
# Training Iter : 393, Acc : 0.3125, Loss : 1.1004
# Training Iter : 394, Acc : 0.25, Loss : 1.0981
# Training Iter : 395, Acc : 0.25, Loss : 1.1032
# Training Iter : 396, Acc : 0.265625, Loss : 1.1021
# Training Iter : 397, Acc : 0.3125, Loss : 1.1063
# Training Iter : 398, Acc : 0.375, Loss : 1.0971
# Training Iter : 399, Acc : 0.25, Loss : 1.1031
# Training Iter : 400, Acc : 0.328125, Loss : 1.0980
# Training Iter : 401, Acc : 0.296875, Loss : 1.0980
# Validation Iter : 401, Acc : 0.375, Loss : 1.0956
# Training Iter : 402, Acc : 0.34375, Loss : 1.0989
# Training Iter : 403, Acc : 0.375, Loss : 1.0979
# Training Iter : 404, Acc : 0.40625, Loss : 1.0952
# Training Iter : 405, Acc : 0.421875, Loss : 1.0994
# Training Iter : 406, Acc : 0.34375, Loss : 1.1021
# Training Iter : 407, Acc : 0.421875, Loss : 1.0945
# Training Iter : 408, Acc : 0.3125, Loss : 1.0991
# Training Iter : 409, Acc : 0.3125, Loss : 1.0971
# Training Iter : 410, Acc : 0.390625, Loss : 1.0921
# Training Iter : 411, Acc : 0.3125, Loss : 1.1004
# Validation Iter : 411, Acc : 0.34375, Loss : 1.0987
# Training Iter : 412, Acc : 0.3125, Loss : 1.0984
# Training Iter : 413, Acc : 0.34375, Loss : 1.0999
# Training Iter : 414, Acc : 0.234375, Loss : 1.0977
# Training Iter : 415, Acc : 0.484375, Loss : 1.0910
# Training Iter : 416, Acc : 0.359375, Loss : 1.0933
# Training Iter : 417, Acc : 0.375, Loss : 1.0941
# Training Iter : 418, Acc : 0.46875, Loss : 1.0978
# Training Iter : 419, Acc : 0.390625, Loss : 1.0997
# Training Iter : 420, Acc : 0.265625, Loss : 1.1019
# Training Iter : 421, Acc : 0.390625, Loss : 1.1015
# Validation Iter : 421, Acc : 0.40625, Loss : 1.0940
# Training Iter : 422, Acc : 0.421875, Loss : 1.0977
# Training Iter : 423, Acc : 0.328125, Loss : 1.1070
# Training Iter : 424, Acc : 0.390625, Loss : 1.0994
# Training Iter : 425, Acc : 0.25, Loss : 1.1048
# Training Iter : 472, Acc : 0.359375, Loss : 1.0975
# Training Iter : 473, Acc : 0.296875, Loss : 1.1008
# Training Iter : 474, Acc : 0.390625, Loss : 1.0949
# Training Iter : 475, Acc : 0.4375, Loss : 1.0787
# Training Iter : 476, Acc : 0.421875, Loss : 1.0705
# Training Iter : 477, Acc : 0.375, Loss : 1.1344
# Training Iter : 478, Acc : 0.34375, Loss : 1.1057
# Training Iter : 479, Acc : 0.484375, Loss : 1.0785
# Training Iter : 480, Acc : 0.40625, Loss : 1.0832
# Training Iter : 481, Acc : 0.421875, Loss : 1.0729
# Validation Iter : 481, Acc : 0.390625, Loss : 1.0994
# Training Iter : 482, Acc : 0.453125, Loss : 1.0632
# Training Iter : 483, Acc : 0.421875, Loss : 1.0678
# Training Iter : 484, Acc : 0.390625, Loss : 1.1055
# Training Iter : 485, Acc : 0.4375, Loss : 1.0701
# Training Iter : 486, Acc : 0.421875, Loss : 1.0868
# Training Iter : 487, Acc : 0.515625, Loss : 1.0083
# Training Iter : 488, Acc : 0.421875, Loss : 1.0608
# Training Iter : 489, Acc : 0.28125, Loss : 1.2324
# Training Iter : 490, Acc : 0.296875, Loss : 1.1117
# Training Iter : 491, Acc : 0.328125, Loss : 1.0768
# Validation Iter : 491, Acc : 0.375, Loss : 1.0654
# Training Iter : 492, Acc : 0.25, Loss : 1.1298
# Training Iter : 493, Acc : 0.453125, Loss : 1.0317
# Training Iter : 494, Acc : 0.265625, Loss : 1.2516
# Training Iter : 495, Acc : 0.3125, Loss : 1.1371
# Training Iter : 496, Acc : 0.40625, Loss : 1.0940
# Training Iter : 497, Acc : 0.390625, Loss : 1.1102
# Training Iter : 498, Acc : 0.359375, Loss : 1.1041
# Training Iter : 499, Acc : 0.484375, Loss : 1.0719
# Training Iter : 500, Acc : 0.296875, Loss : 1.0885
# Training Iter : 501, Acc : 0.390625, Loss : 1.0915
# Validation Iter : 501, Acc : 0.25, Loss : 1.1270
# Training Iter : 502, Acc : 0.265625, Loss : 1.0851
# Training Iter : 503, Acc : 0.453125, Loss : 1.0684
# Training Iter : 504, Acc : 0.359375, Loss : 1.1245
# Training Iter : 505, Acc : 0.421875, Loss : 1.0633
# Training Iter : 506, Acc : 0.328125, Loss : 1.1096
# Training Iter : 507, Acc : 0.421875, Loss : 1.0785
# Training Iter : 508, Acc : 0.21875, Loss : 1.1458
# Training Iter : 509, Acc : 0.390625, Loss : 1.1076
# Training Iter : 510, Acc : 0.453125, Loss : 1.0688
# Training Iter : 511, Acc : 0.34375, Loss : 1.1039
# Validation Iter : 511, Acc : 0.421875, Loss : 1.0742
# Training Iter : 512, Acc : 0.484375, Loss : 1.0793
# Training Iter : 513, Acc : 0.390625, Loss : 1.0972
# Training Iter : 514, Acc : 0.359375, Loss : 1.0971
# Training Iter : 515, Acc : 0.390625, Loss : 1.0893
# Training Iter : 516, Acc : 0.40625, Loss : 1.0940
# Training Iter : 517, Acc : 0.296875, Loss : 1.1019
# Training Iter : 518, Acc : 0.265625, Loss : 1.1128
# Training Iter : 519, Acc : 0.203125, Loss : 1.1135
# Training Iter : 520, Acc : 0.25, Loss : 1.1018
# Training Iter : 521, Acc : 0.375, Loss : 1.0854
# Validation Iter : 521, Acc : 0.234375, Loss : 1.1385
# Training Iter : 522, Acc : 0.3125, Loss : 1.1199
# Training Iter : 523, Acc : 0.390625, Loss : 1.0958
# Training Iter : 524, Acc : 0.25, Loss : 1.1017
# Training Iter : 525, Acc : 0.34375, Loss : 1.0971
# Training Iter : 526, Acc : 0.25, Loss : 1.1413
# Training Iter : 527, Acc : 0.265625, Loss : 1.0985
# Training Iter : 528, Acc : 0.265625, Loss : 1.0960
# Training Iter : 529, Acc : 0.328125, Loss : 1.0962
# Training Iter : 530, Acc : 0.3125, Loss : 1.0982
# Training Iter : 531, Acc : 0.40625, Loss : 1.0941
# Validation Iter : 531, Acc : 0.359375, Loss : 1.1040
# Training Iter : 532, Acc : 0.328125, Loss : 1.1005
# Training Iter : 533, Acc : 0.390625, Loss : 1.1040
# Training Iter : 534, Acc : 0.390625, Loss : 1.0991
# Training Iter : 535, Acc : 0.40625, Loss : 1.0914
# Training Iter : 536, Acc : 0.5, Loss : 1.0900
# Training Iter : 537, Acc : 0.390625, Loss : 1.0887
# Training Iter : 538, Acc : 0.546875, Loss : 1.0905
# Training Iter : 539, Acc : 0.484375, Loss : 1.0834
# Training Iter : 540, Acc : 0.46875, Loss : 1.0876
# Training Iter : 541, Acc : 0.3125, Loss : 1.1003
# Validation Iter : 541, Acc : 0.3125, Loss : 1.0998
# Training Iter : 542, Acc : 0.171875, Loss : 1.1048
# Training Iter : 543, Acc : 0.421875, Loss : 1.0919
# Training Iter : 544, Acc : 0.328125, Loss : 1.1177
# Training Iter : 545, Acc : 0.4375, Loss : 1.0925
# Training Iter : 546, Acc : 0.359375, Loss : 1.0875
# Training Iter : 547, Acc : 0.453125, Loss : 1.0891
# Training Iter : 548, Acc : 0.4375, Loss : 1.0935
# Training Iter : 549, Acc : 0.375, Loss : 1.0983
# Training Iter : 550, Acc : 0.375, Loss : 1.1003
# Training Iter : 551, Acc : 0.421875, Loss : 1.0946
# Validation Iter : 551, Acc : 0.296875, Loss : 1.0986
# Training Iter : 552, Acc : 0.484375, Loss : 1.0930
# Training Iter : 553, Acc : 0.453125, Loss : 1.0915
# Training Iter : 554, Acc : 0.421875, Loss : 1.0809
# Training Iter : 555, Acc : 0.328125, Loss : 1.1017
# Training Iter : 556, Acc : 0.375, Loss : 1.0868
# Training Iter : 557, Acc : 0.40625, Loss : 1.0794
# Training Iter : 558, Acc : 0.421875, Loss : 1.0720
# Training Iter : 559, Acc : 0.46875, Loss : 1.0818
# Training Iter : 560, Acc : 0.453125, Loss : 1.0464
# Training Iter : 561, Acc : 0.421875, Loss : 1.1014
# Validation Iter : 561, Acc : 0.28125, Loss : 1.1214
# Training Iter : 562, Acc : 0.25, Loss : 1.1573
# Training Iter : 563, Acc : 0.203125, Loss : 1.1011
# Training Iter : 611, Acc : 0.390625, Loss : 1.0843
# Validation Iter : 611, Acc : 0.25, Loss : 1.1743
# Training Iter : 612, Acc : 0.296875, Loss : 1.0900
# Training Iter : 613, Acc : 0.4375, Loss : 1.0682
# Training Iter : 614, Acc : 0.4375, Loss : 1.0551
# Training Iter : 615, Acc : 0.4375, Loss : 1.0170
# Training Iter : 616, Acc : 0.390625, Loss : 1.0334
# Training Iter : 617, Acc : 0.359375, Loss : 1.1450
# Training Iter : 618, Acc : 0.4375, Loss : 1.0614
# Training Iter : 619, Acc : 0.34375, Loss : 1.1141
# Training Iter : 620, Acc : 0.296875, Loss : 1.1541
# Training Iter : 621, Acc : 0.1875, Loss : 1.1392
# Validation Iter : 621, Acc : 0.15625, Loss : 1.1279
# Training Iter : 622, Acc : 0.28125, Loss : 1.1066
# Training Iter : 623, Acc : 0.296875, Loss : 1.0973
# Training Iter : 624, Acc : 0.328125, Loss : 1.0988
# Training Iter : 625, Acc : 0.34375, Loss : 1.0876
# Training Iter : 626, Acc : 0.375, Loss : 1.0961
# Training Iter : 627, Acc : 0.3125, Loss : 1.0972
# Training Iter : 628, Acc : 0.390625, Loss : 1.0958
# Training Iter : 629, Acc : 0.328125, Loss : 1.0965
# Training Iter : 630, Acc : 0.453125, Loss : 1.0984
# Training Iter : 631, Acc : 0.28125, Loss : 1.1010
# Validation Iter : 631, Acc : 0.28125, Loss : 1.1181
# Training Iter : 632, Acc : 0.296875, Loss : 1.1048
# Training Iter : 633, Acc : 0.28125, Loss : 1.1150
# Training Iter : 634, Acc : 0.34375, Loss : 1.0977
# Training Iter : 635, Acc : 0.359375, Loss : 1.1007
# Training Iter : 636, Acc : 0.453125, Loss : 1.0920
# Training Iter : 637, Acc : 0.53125, Loss : 1.0803
# Training Iter : 638, Acc : 0.375, Loss : 1.0846
# Training Iter : 639, Acc : 0.421875, Loss : 1.1113
# Training Iter : 640, Acc : 0.359375, Loss : 1.1100
# Training Iter : 641, Acc : 0.328125, Loss : 1.1017
# Validation Iter : 641, Acc : 0.25, Loss : 1.1140
# Training Iter : 642, Acc : 0.4375, Loss : 1.0839
# Training Iter : 643, Acc : 0.421875, Loss : 1.0882
# Training Iter : 644, Acc : 0.40625, Loss : 1.0829
# Training Iter : 645, Acc : 0.484375, Loss : 1.0673
# Training Iter : 646, Acc : 0.5, Loss : 1.0305
# Training Iter : 647, Acc : 0.453125, Loss : 1.0460
# Training Iter : 648, Acc : 0.484375, Loss : 1.0544
# Training Iter : 649, Acc : 0.390625, Loss : 1.0852
# Training Iter : 650, Acc : 0.28125, Loss : 1.1367
# Training Iter : 651, Acc : 0.34375, Loss : 1.0841
# Validation Iter : 651, Acc : 0.3125, Loss : 1.0941
# Training Iter : 652, Acc : 0.4375, Loss : 1.0818
# Training Iter : 653, Acc : 0.34375, Loss : 1.1112
# Training Iter : 654, Acc : 0.296875, Loss : 1.0954
# Training Iter : 655, Acc : 0.53125, Loss : 1.0742
# Training Iter : 656, Acc : 0.515625, Loss : 1.0550
# Training Iter : 657, Acc : 0.34375, Loss : 1.1181
# Training Iter : 658, Acc : 0.3125, Loss : 1.1216
# Training Iter : 659, Acc : 0.3125, Loss : 1.1259
# Training Iter : 660, Acc : 0.265625, Loss : 1.0973
# Training Iter : 661, Acc : 0.34375, Loss : 1.1006
# Validation Iter : 661, Acc : 0.28125, Loss : 1.0987
# Training Iter : 662, Acc : 0.421875, Loss : 1.0891
# Training Iter : 663, Acc : 0.296875, Loss : 1.1042
# Training Iter : 664, Acc : 0.390625, Loss : 1.1083
# Training Iter : 665, Acc : 0.296875, Loss : 1.1081
# Training Iter : 666, Acc : 0.296875, Loss : 1.1068
# Training Iter : 667, Acc : 0.328125, Loss : 1.1019
# Training Iter : 668, Acc : 0.296875, Loss : 1.1132
# Training Iter : 669, Acc : 0.359375, Loss : 1.0993
# Training Iter : 670, Acc : 0.265625, Loss : 1.1112
# Training Iter : 671, Acc : 0.34375, Loss : 1.1040
# Validation Iter : 671, Acc : 0.34375, Loss : 1.0940
# Training Iter : 672, Acc : 0.328125, Loss : 1.1001
# Training Iter : 673, Acc : 0.359375, Loss : 1.0977
# Training Iter : 674, Acc : 0.375, Loss : 1.0915
# Training Iter : 675, Acc : 0.265625, Loss : 1.0969
# Training Iter : 676, Acc : 0.3125, Loss : 1.0974
# Training Iter : 677, Acc : 0.296875, Loss : 1.0960
# Training Iter : 678, Acc : 0.296875, Loss : 1.0949
# Training Iter : 679, Acc : 0.328125, Loss : 1.0966
# Training Iter : 680, Acc : 0.328125, Loss : 1.0978
# Training Iter : 681, Acc : 0.34375, Loss : 1.1014
# Validation Iter : 681, Acc : 0.453125, Loss : 1.0969
# Training Iter : 682, Acc : 0.28125, Loss : 1.1035
# Training Iter : 683, Acc : 0.28125, Loss : 1.0966
# Training Iter : 684, Acc : 0.25, Loss : 1.0962
# Training Iter : 685, Acc : 0.375, Loss : 1.0925
# Training Iter : 686, Acc : 0.3125, Loss : 1.0974
# Training Iter : 687, Acc : 0.359375, Loss : 1.0968
# Training Iter : 688, Acc : 0.15625, Loss : 1.1029
# Training Iter : 689, Acc : 0.34375, Loss : 1.0996
# Training Iter : 690, Acc : 0.296875, Loss : 1.0940
# Training Iter : 691, Acc : 0.234375, Loss : 1.1129
# Validation Iter : 691, Acc : 0.34375, Loss : 1.0970
# Training Iter : 692, Acc : 0.34375, Loss : 1.0977
# Training Iter : 693, Acc : 0.390625, Loss : 1.0933
# Training Iter : 694, Acc : 0.421875, Loss : 1.0891
# Training Iter : 695, Acc : 0.296875, Loss : 1.1769
# Training Iter : 696, Acc : 0.3125, Loss : 1.1019
# Training Iter : 697, Acc : 0.28125, Loss : 1.1049
# Training Iter : 698, Acc : 0.3125, Loss : 1.1013
# Training Iter : 699, Acc : 0.375, Loss : 1.0992
# Training Iter : 700, Acc : 0.34375, Loss : 1.0980
# Training Iter : 701, Acc : 0.296875, Loss : 1.0992
# Validation Iter : 701, Acc : 0.40625, Loss : 1.0956
# Training Iter : 702, Acc : 0.359375, Loss : 1.0989
# Training Iter : 703, Acc : 0.359375, Loss : 1.0980
# Training Iter : 704, Acc : 0.3125, Loss : 1.1058
# Training Iter : 705, Acc : 0.328125, Loss : 1.1007
# Training Iter : 706, Acc : 0.34375, Loss : 1.0942
# Training Iter : 707, Acc : 0.3125, Loss : 1.1008
# Training Iter : 708, Acc : 0.40625, Loss : 1.0980
# Training Iter : 709, Acc : 0.28125, Loss : 1.1009
# Training Iter : 710, Acc : 0.328125, Loss : 1.0990
# Training Iter : 711, Acc : 0.3125, Loss : 1.0990
# Validation Iter : 711, Acc : 0.421875, Loss : 1.0956
# Training Iter : 712, Acc : 0.25, Loss : 1.1008
# Training Iter : 713, Acc : 0.359375, Loss : 1.0967
# Training Iter : 714, Acc : 0.34375, Loss : 1.0975
# Training Iter : 715, Acc : 0.359375, Loss : 1.0976
# Training Iter : 716, Acc : 0.34375, Loss : 1.0938
# Training Iter : 717, Acc : 0.359375, Loss : 1.0972
# Training Iter : 718, Acc : 0.21875, Loss : 1.1051
# Training Iter : 719, Acc : 0.34375, Loss : 1.0941
# Training Iter : 720, Acc : 0.4375, Loss : 1.0951
# Training Iter : 721, Acc : 0.359375, Loss : 1.0969
# Validation Iter : 721, Acc : 0.390625, Loss : 1.0947
# Training Iter : 722, Acc : 0.265625, Loss : 1.1058
# Training Iter : 723, Acc : 0.3125, Loss : 1.1036
# Training Iter : 724, Acc : 0.359375, Loss : 1.0972
# Training Iter : 725, Acc : 0.359375, Loss : 1.0967
# Training Iter : 726, Acc : 0.4375, Loss : 1.0906
# Training Iter : 727, Acc : 0.359375, Loss : 1.0925
# Training Iter : 728, Acc : 0.375, Loss : 1.0906
# Training Iter : 729, Acc : 0.265625, Loss : 1.1115
# Training Iter : 730, Acc : 0.328125, Loss : 1.1026
# Training Iter : 731, Acc : 0.375, Loss : 1.0986
# Validation Iter : 731, Acc : 0.359375, Loss : 1.0954
# Training Iter : 732, Acc : 0.296875, Loss : 1.1050
# Training Iter : 733, Acc : 0.296875, Loss : 1.1030
# Training Iter : 734, Acc : 0.359375, Loss : 1.0997
# Training Iter : 735, Acc : 0.265625, Loss : 1.1050
# Training Iter : 736, Acc : 0.421875, Loss : 1.0968
# Training Iter : 737, Acc : 0.390625, Loss : 1.0967
# Training Iter : 738, Acc : 0.28125, Loss : 1.1003
# Training Iter : 739, Acc : 0.296875, Loss : 1.1014
# Training Iter : 740, Acc : 0.296875, Loss : 1.1035
# Training Iter : 741, Acc : 0.3125, Loss : 1.0990
# Validation Iter : 741, Acc : 0.28125, Loss : 1.1011
# Training Iter : 742, Acc : 0.421875, Loss : 1.0961
# Training Iter : 743, Acc : 0.53125, Loss : 1.0973
# Training Iter : 744, Acc : 0.421875, Loss : 1.0916
# Training Iter : 745, Acc : 0.390625, Loss : 1.0929
# Training Iter : 746, Acc : 0.296875, Loss : 1.1081
# Training Iter : 747, Acc : 0.359375, Loss : 1.1013
# Training Iter : 748, Acc : 0.359375, Loss : 1.0894
# Training Iter : 749, Acc : 0.390625, Loss : 1.0878
# Training Iter : 750, Acc : 0.3125, Loss : 1.1066
# Training Iter : 751, Acc : 0.34375, Loss : 1.0965
# Validation Iter : 751, Acc : 0.3125, Loss : 1.1003
# Training Iter : 752, Acc : 0.25, Loss : 1.1118
# Training Iter : 753, Acc : 0.375, Loss : 1.0956
# Training Iter : 754, Acc : 0.40625, Loss : 1.0932
# Training Iter : 755, Acc : 0.453125, Loss : 1.0829
# Training Iter : 756, Acc : 0.421875, Loss : 1.0973
# Training Iter : 757, Acc : 0.359375, Loss : 1.0840
# Training Iter : 758, Acc : 0.328125, Loss : 1.1058
# Training Iter : 759, Acc : 0.328125, Loss : 1.1044
# Training Iter : 760, Acc : 0.40625, Loss : 1.0926
# Training Iter : 761, Acc : 0.28125, Loss : 1.0985
# Validation Iter : 761, Acc : 0.40625, Loss : 1.0953
# Training Iter : 762, Acc : 0.390625, Loss : 1.0863
# Training Iter : 763, Acc : 0.359375, Loss : 1.0912
# Training Iter : 764, Acc : 0.34375, Loss : 1.1054
# Training Iter : 765, Acc : 0.46875, Loss : 1.0791
# Training Iter : 766, Acc : 0.328125, Loss : 1.0877
# Training Iter : 767, Acc : 0.28125, Loss : 1.0908
# Training Iter : 768, Acc : 0.4375, Loss : 1.0657
# Training Iter : 769, Acc : 0.375, Loss : 1.1000
# Training Iter : 770, Acc : 0.390625, Loss : 1.0854
# Training Iter : 771, Acc : 0.296875, Loss : 1.0760
# Validation Iter : 771, Acc : 0.40625, Loss : 1.0757
# Training Iter : 772, Acc : 0.421875, Loss : 1.0836
# Training Iter : 773, Acc : 0.3125, Loss : 1.1298
# Training Iter : 774, Acc : 0.3125, Loss : 1.1039
# Training Iter : 775, Acc : 0.40625, Loss : 1.0817
# Training Iter : 776, Acc : 0.296875, Loss : 1.1296
# Training Iter : 777, Acc : 0.40625, Loss : 1.0884
# Training Iter : 778, Acc : 0.296875, Loss : 1.1102
# Training Iter : 779, Acc : 0.375, Loss : 1.1024
# Training Iter : 780, Acc : 0.453125, Loss : 1.0939
# Training Iter : 781, Acc : 0.390625, Loss : 1.0971
# Validation Iter : 781, Acc : 0.3125, Loss : 1.1024
# Training Iter : 782, Acc : 0.375, Loss : 1.0873
# Training Iter : 783, Acc : 0.328125, Loss : 1.0921
# Training Iter : 784, Acc : 0.296875, Loss : 1.1009
# Training Iter : 785, Acc : 0.4375, Loss : 1.0779
# Training Iter : 786, Acc : 0.453125, Loss : 1.0799
# Training Iter : 787, Acc : 0.484375, Loss : 1.0660
# Training Iter : 788, Acc : 0.421875, Loss : 1.0755
# Training Iter : 789, Acc : 0.421875, Loss : 1.0751
# Training Iter : 790, Acc : 0.28125, Loss : 1.0983
# Training Iter : 791, Acc : 0.40625, Loss : 1.0864
# Validation Iter : 791, Acc : 0.328125, Loss : 1.0998
# Training Iter : 792, Acc : 0.390625, Loss : 1.0877
# Training Iter : 793, Acc : 0.359375, Loss : 1.1136
# Training Iter : 794, Acc : 0.359375, Loss : 1.0823
# Training Iter : 795, Acc : 0.328125, Loss : 1.1400
# Training Iter : 796, Acc : 0.359375, Loss : 1.0865
# Training Iter : 797, Acc : 0.25, Loss : 1.1071
# Training Iter : 798, Acc : 0.3125, Loss : 1.1120
# Training Iter : 799, Acc : 0.3125, Loss : 1.1068
# Training Iter : 800, Acc : 0.296875, Loss : 1.1048
# Training Iter : 801, Acc : 0.375, Loss : 1.0962
# Validation Iter : 801, Acc : 0.265625, Loss : 1.1140
# Training Iter : 802, Acc : 0.359375, Loss : 1.0972
# Training Iter : 803, Acc : 0.40625, Loss : 1.0946
# Training Iter : 804, Acc : 0.359375, Loss : 1.0994
# Training Iter : 805, Acc : 0.265625, Loss : 1.0994
# Training Iter : 806, Acc : 0.375, Loss : 1.0849
# Training Iter : 807, Acc : 0.359375, Loss : 1.0925
# Training Iter : 808, Acc : 0.265625, Loss : 1.1948
# Training Iter : 809, Acc : 0.453125, Loss : 1.1034
# Training Iter : 810, Acc : 0.453125, Loss : 1.0964
# Training Iter : 811, Acc : 0.265625, Loss : 1.1089
# Validation Iter : 811, Acc : 0.28125, Loss : 1.1026
# Training Iter : 812, Acc : 0.296875, Loss : 1.0958
# Training Iter : 813, Acc : 0.34375, Loss : 1.1017
# Training Iter : 814, Acc : 0.34375, Loss : 1.1003
# Training Iter : 815, Acc : 0.359375, Loss : 1.0989
# Training Iter : 816, Acc : 0.34375, Loss : 1.0987
# Training Iter : 817, Acc : 0.359375, Loss : 1.1008
# Training Iter : 818, Acc : 0.296875, Loss : 1.0981
# Training Iter : 819, Acc : 0.296875, Loss : 1.0974
# Training Iter : 820, Acc : 0.328125, Loss : 1.0996
# Training Iter : 821, Acc : 0.421875, Loss : 1.1002
# Validation Iter : 821, Acc : 0.28125, Loss : 1.1008
# Training Iter : 822, Acc : 0.28125, Loss : 1.1014
# Training Iter : 823, Acc : 0.359375, Loss : 1.0970
# Training Iter : 824, Acc : 0.328125, Loss : 1.0898
# Training Iter : 825, Acc : 0.390625, Loss : 1.0962
# Training Iter : 826, Acc : 0.375, Loss : 1.0955
# Training Iter : 827, Acc : 0.375, Loss : 1.0990
# Training Iter : 828, Acc : 0.34375, Loss : 1.0980
# Training Iter : 829, Acc : 0.40625, Loss : 1.0904
# Training Iter : 830, Acc : 0.265625, Loss : 1.1118
# Training Iter : 831, Acc : 0.4375, Loss : 1.0802
# Validation Iter : 831, Acc : 0.265625, Loss : 1.1102
# Training Iter : 832, Acc : 0.390625, Loss : 1.0956
# Training Iter : 833, Acc : 0.40625, Loss : 1.0938
# Training Iter : 834, Acc : 0.296875, Loss : 1.1019
# Training Iter : 835, Acc : 0.265625, Loss : 1.1066
# Training Iter : 836, Acc : 0.390625, Loss : 1.0880
# Training Iter : 837, Acc : 0.34375, Loss : 1.0947
# Training Iter : 838, Acc : 0.28125, Loss : 1.1137
# Training Iter : 839, Acc : 0.3125, Loss : 1.0953
# Training Iter : 840, Acc : 0.4375, Loss : 1.0743
# Training Iter : 841, Acc : 0.390625, Loss : 1.0808
# Validation Iter : 841, Acc : 0.421875, Loss : 1.1068
# Training Iter : 842, Acc : 0.390625, Loss : 1.0869
# Training Iter : 843, Acc : 0.28125, Loss : 1.0871
# Training Iter : 844, Acc : 0.296875, Loss : 1.1264
# Training Iter : 845, Acc : 0.328125, Loss : 1.0990
# Training Iter : 846, Acc : 0.296875, Loss : 1.1058
# Training Iter : 847, Acc : 0.328125, Loss : 1.0952
# Training Iter : 848, Acc : 0.390625, Loss : 1.0893
# Training Iter : 849, Acc : 0.359375, Loss : 1.1150
# Training Iter : 850, Acc : 0.4375, Loss : 1.0985
# Training Iter : 851, Acc : 0.34375, Loss : 1.1072
# Validation Iter : 851, Acc : 0.359375, Loss : 1.1023
# Training Iter : 852, Acc : 0.4375, Loss : 1.0991
# Training Iter : 853, Acc : 0.421875, Loss : 1.0894
# Training Iter : 854, Acc : 0.25, Loss : 1.1218
# Training Iter : 855, Acc : 0.296875, Loss : 1.0964
# Training Iter : 856, Acc : 0.4375, Loss : 1.0979
# Training Iter : 857, Acc : 0.5, Loss : 1.0843
# Training Iter : 858, Acc : 0.328125, Loss : 1.1096
# Training Iter : 859, Acc : 0.28125, Loss : 1.1053
# Training Iter : 860, Acc : 0.359375, Loss : 1.0980
# Training Iter : 861, Acc : 0.34375, Loss : 1.1066
# Validation Iter : 861, Acc : 0.28125, Loss : 1.0967
# Training Iter : 862, Acc : 0.328125, Loss : 1.0966
# Training Iter : 863, Acc : 0.328125, Loss : 1.1407
# Training Iter : 864, Acc : 0.390625, Loss : 1.0970
# Training Iter : 865, Acc : 0.421875, Loss : 1.0983
# Training Iter : 866, Acc : 0.390625, Loss : 1.0879
# Training Iter : 867, Acc : 0.4375, Loss : 1.0956
# Training Iter : 868, Acc : 0.25, Loss : 1.1192
# Training Iter : 869, Acc : 0.296875, Loss : 1.1038
# Training Iter : 870, Acc : 0.5625, Loss : 1.0795
# ...
# Training Iter : 5763, Acc : 0.28125, Loss : 1.1109
# Training Iter : 5764, Acc : 0.328125, Loss : 1.1089
# Training Iter : 5765, Acc : 0.28125, Loss : 1.1160
# Training Iter : 5766, Acc : 0.3125, Loss : 1.0956
# Training Iter : 5767, Acc : 0.28125, Loss : 1.0888
# Training Iter : 5768, Acc : 0.359375, Loss : 1.0902
# Training Iter : 5769, Acc : 0.34375, Loss : 1.0971
# Training Iter : 5770, Acc : 0.421875, Loss : 1.0849
# Training Iter : 5771, Acc : 0.53125, Loss : 1.0796
# Validation Iter : 5771, Acc : 0.28125, Loss : 1.1132
# Training Iter : 5772, Acc : 0.40625, Loss : 1.0722
# Training Iter : 5773, Acc : 0.25, Loss : 1.1057
# Training Iter : 5774, Acc : 0.25, Loss : 1.1057
# Training Iter : 5775, Acc : 0.28125, Loss : 1.1028
# Training Iter : 5776, Acc : 0.28125, Loss : 1.0880
# Training Iter : 5777, Acc : 0.421875, Loss : 1.0958
# Training Iter : 5778, Acc : 0.390625, Loss : 1.0920
# Training Iter : 5779, Acc : 0.359375, Loss : 1.1162
# Training Iter : 5780, Acc : 0.296875, Loss : 1.0991
# Training Iter : 5781, Acc : 0.34375, Loss : 1.1037
# Validation Iter : 5781, Acc : 0.28125, Loss : 1.1121
# Training Iter : 5782, Acc : 0.3125, Loss : 1.1055
# Training Iter : 5783, Acc : 0.265625, Loss : 1.1115
# Training Iter : 5784, Acc : 0.265625, Loss : 1.1047
# Training Iter : 5785, Acc : 0.34375, Loss : 1.0913
# Training Iter : 5786, Acc : 0.40625, Loss : 1.0885
# Training Iter : 5787, Acc : 0.390625, Loss : 1.0930
# Training Iter : 5788, Acc : 0.3125, Loss : 1.1048
# Training Iter : 5789, Acc : 0.40625, Loss : 1.0920
# Training Iter : 5790, Acc : 0.34375, Loss : 1.1035
# Training Iter : 5791, Acc : 0.328125, Loss : 1.0928
# Validation Iter : 5791, Acc : 0.359375, Loss : 1.1026
# Training Iter : 5792, Acc : 0.265625, Loss : 1.0988
# Training Iter : 5793, Acc : 0.265625, Loss : 1.0999
# Training Iter : 5794, Acc : 0.328125, Loss : 1.1120
# Training Iter : 5795, Acc : 0.421875, Loss : 1.0938
# Training Iter : 5796, Acc : 0.421875, Loss : 1.0805
# Training Iter : 5797, Acc : 0.265625, Loss : 1.0988
# Training Iter : 5798, Acc : 0.421875, Loss : 1.0839
# Training Iter : 5799, Acc : 0.265625, Loss : 1.1115
# Training Iter : 5800, Acc : 0.34375, Loss : 1.0920
# Training Iter : 5801, Acc : 0.515625, Loss : 1.0782
# Validation Iter : 5801, Acc : 0.21875, Loss : 1.1142
# Training Iter : 5802, Acc : 0.375, Loss : 1.0931
# Training Iter : 5803, Acc : 0.296875, Loss : 1.0913
# Training Iter : 5804, Acc : 0.359375, Loss : 1.0891
# Training Iter : 5805, Acc : 0.515625, Loss : 1.0776
# Training Iter : 5806, Acc : 0.359375, Loss : 1.0918
# Training Iter : 5807, Acc : 0.4375, Loss : 1.0797
# Training Iter : 5808, Acc : 0.46875, Loss : 1.0787
# Training Iter : 5809, Acc : 0.421875, Loss : 1.0798
# Training Iter : 5810, Acc : 0.5, Loss : 1.0650
# Training Iter : 5811, Acc : 0.546875, Loss : 1.0425
# Validation Iter : 5811, Acc : 0.4375, Loss : 1.0592
# Training Iter : 5812, Acc : 0.328125, Loss : 1.0862
# Training Iter : 5813, Acc : 0.390625, Loss : 1.0798
# Training Iter : 5814, Acc : 0.390625, Loss : 1.0822
# Training Iter : 5815, Acc : 0.34375, Loss : 1.1087
# Training Iter : 5816, Acc : 0.25, Loss : 1.1323
# Training Iter : 5817, Acc : 0.28125, Loss : 1.1015
# Training Iter : 5818, Acc : 0.4375, Loss : 1.0734
# Training Iter : 5819, Acc : 0.3125, Loss : 1.0885
# Training Iter : 5820, Acc : 0.28125, Loss : 1.1263
# Training Iter : 5821, Acc : 0.375, Loss : 1.0910
# Validation Iter : 5821, Acc : 0.5, Loss : 1.0730
# Training Iter : 5822, Acc : 0.453125, Loss : 1.0694
# Training Iter : 5823, Acc : 0.28125, Loss : 1.1455
# Training Iter : 5824, Acc : 0.328125, Loss : 1.0927
# Training Iter : 5825, Acc : 0.375, Loss : 1.0798
# Training Iter : 5826, Acc : 0.390625, Loss : 1.1276
# Training Iter : 5827, Acc : 0.546875, Loss : 1.0597
# Training Iter : 5828, Acc : 0.390625, Loss : 1.0699
# Training Iter : 5829, Acc : 0.34375, Loss : 1.0928
# Training Iter : 5830, Acc : 0.296875, Loss : 1.0905
# Training Iter : 5831, Acc : 0.390625, Loss : 1.1038
# Validation Iter : 5831, Acc : 0.34375, Loss : 1.1096
# Training Iter : 5832, Acc : 0.53125, Loss : 1.0486
# Training Iter : 5833, Acc : 0.375, Loss : 1.1130
# Training Iter : 5834, Acc : 0.34375, Loss : 1.0964
# Training Iter : 5835, Acc : 0.4375, Loss : 1.0569
# Training Iter : 5836, Acc : 0.25, Loss : 1.1115
# Training Iter : 5837, Acc : 0.390625, Loss : 1.0889
# Training Iter : 5838, Acc : 0.421875, Loss : 1.0802
# Training Iter : 5839, Acc : 0.375, Loss : 1.0848
# Training Iter : 5840, Acc : 0.359375, Loss : 1.0859
# Training Iter : 5841, Acc : 0.34375, Loss : 1.0948
# Validation Iter : 5841, Acc : 0.375, Loss : 1.0749
# Training Iter : 5842, Acc : 0.28125, Loss : 1.0993
# Training Iter : 5843, Acc : 0.359375, Loss : 1.0834
# Training Iter : 5844, Acc : 0.40625, Loss : 1.0731
# Training Iter : 5845, Acc : 0.265625, Loss : 1.1392
# Training Iter : 5846, Acc : 0.21875, Loss : 1.1221
# Training Iter : 5847, Acc : 0.265625, Loss : 1.1232
# Training Iter : 5848, Acc : 0.265625, Loss : 1.1355
# Training Iter : 5849, Acc : 0.40625, Loss : 1.0886
# Training Iter : 5850, Acc : 0.328125, Loss : 1.1242
# Training Iter : 5851, Acc : 0.453125, Loss : 1.0836
# Validation Iter : 5851, Acc : 0.296875, Loss : 1.1166
# Training Iter : 5852, Acc : 0.203125, Loss : 1.1106
# Training Iter : 5853, Acc : 0.328125, Loss : 1.0979
# Training Iter : 5854, Acc : 0.34375, Loss : 1.0963
# Training Iter : 5855, Acc : 0.375, Loss : 1.0949
# Training Iter : 5856, Acc : 0.453125, Loss : 1.0702
# Training Iter : 5857, Acc : 0.421875, Loss : 1.0919
# Training Iter : 5858, Acc : 0.375, Loss : 1.0891
# Training Iter : 5859, Acc : 0.46875, Loss : 1.0794
# Training Iter : 5860, Acc : 0.390625, Loss : 1.0649
# Training Iter : 5861, Acc : 0.4375, Loss : 1.0382
# Validation Iter : 5861, Acc : 0.296875, Loss : 1.1263
# Training Iter : 5862, Acc : 0.390625, Loss : 1.0495
# Training Iter : 5863, Acc : 0.46875, Loss : 1.0257
# Training Iter : 5864, Acc : 0.34375, Loss : 1.0318
# Training Iter : 5865, Acc : 0.5, Loss : 1.0386
# Training Iter : 5866, Acc : 0.46875, Loss : 1.0289
# Training Iter : 5867, Acc : 0.40625, Loss : 1.0452
# Training Iter : 5868, Acc : 0.53125, Loss : 1.0128
# Training Iter : 5869, Acc : 0.46875, Loss : 1.0662
# Training Iter : 5870, Acc : 0.34375, Loss : 1.0624
# Training Iter : 5871, Acc : 0.40625, Loss : 1.0550
# Validation Iter : 5871, Acc : 0.390625, Loss : 1.0545
# Training Iter : 5872, Acc : 0.25, Loss : 1.1360
# Training Iter : 5873, Acc : 0.34375, Loss : 1.0849
# Training Iter : 5874, Acc : 0.453125, Loss : 1.0305
# Training Iter : 5875, Acc : 0.40625, Loss : 1.0567
# Training Iter : 5876, Acc : 0.390625, Loss : 1.0330
# Training Iter : 5877, Acc : 0.40625, Loss : 1.0567
# Training Iter : 5878, Acc : 0.359375, Loss : 1.0986
# Training Iter : 5879, Acc : 0.453125, Loss : 1.0530
# Training Iter : 5880, Acc : 0.203125, Loss : 1.1155
# Training Iter : 5881, Acc : 0.421875, Loss : 1.0307
# Validation Iter : 5881, Acc : 0.265625, Loss : 1.0830
# Training Iter : 5882, Acc : 0.5625, Loss : 1.0018
# Training Iter : 5883, Acc : 0.4375, Loss : 1.0043
# Training Iter : 5884, Acc : 0.328125, Loss : 1.0761
# Training Iter : 5885, Acc : 0.265625, Loss : 1.2267
# Training Iter : 5886, Acc : 0.453125, Loss : 1.0802
# Training Iter : 5887, Acc : 0.390625, Loss : 1.0829
# Training Iter : 5888, Acc : 0.34375, Loss : 1.1319
# Training Iter : 5889, Acc : 0.34375, Loss : 1.1582
# Training Iter : 5890, Acc : 0.3125, Loss : 1.0871
# Training Iter : 5891, Acc : 0.453125, Loss : 1.0459
# Validation Iter : 5891, Acc : 0.21875, Loss : 1.1214
# Training Iter : 5892, Acc : 0.421875, Loss : 1.0605
# Training Iter : 5893, Acc : 0.375, Loss : 1.0541
# Training Iter : 5894, Acc : 0.125, Loss : 1.1617
# Training Iter : 5895, Acc : 0.28125, Loss : 1.1264
# Training Iter : 5896, Acc : 0.28125, Loss : 1.0986
# Training Iter : 5897, Acc : 0.21875, Loss : 1.0984
# Training Iter : 5898, Acc : 0.4375, Loss : 1.0757
# Training Iter : 5899, Acc : 0.375, Loss : 1.1254
# Training Iter : 5900, Acc : 0.3125, Loss : 1.0920
# Training Iter : 5901, Acc : 0.390625, Loss : 1.1113
# Validation Iter : 5901, Acc : 0.234375, Loss : 1.1097
# Training Iter : 5902, Acc : 0.328125, Loss : 1.0957
# Training Iter : 5903, Acc : 0.3125, Loss : 1.0950
# Training Iter : 5904, Acc : 0.375, Loss : 1.0873
# Training Iter : 5905, Acc : 0.421875, Loss : 1.1004
# Training Iter : 5906, Acc : 0.375, Loss : 1.0833
# Training Iter : 5907, Acc : 0.421875, Loss : 1.0723
# Training Iter : 5908, Acc : 0.46875, Loss : 1.0615
# Training Iter : 5909, Acc : 0.375, Loss : 1.0807
# Training Iter : 5910, Acc : 0.40625, Loss : 1.0588
# Training Iter : 5911, Acc : 0.375, Loss : 1.0895
# Validation Iter : 5911, Acc : 0.453125, Loss : 1.0454
# Training Iter : 5912, Acc : 0.40625, Loss : 1.0830
# Training Iter : 5913, Acc : 0.375, Loss : 1.1184
# Training Iter : 5914, Acc : 0.390625, Loss : 1.0834
# Training Iter : 5915, Acc : 0.421875, Loss : 1.0485
# Training Iter : 5916, Acc : 0.203125, Loss : 1.1584
# Training Iter : 5917, Acc : 0.34375, Loss : 1.0904
# Training Iter : 5918, Acc : 0.296875, Loss : 1.1003
# Training Iter : 5919, Acc : 0.296875, Loss : 1.1008
# Training Iter : 5920, Acc : 0.453125, Loss : 1.0902
# Training Iter : 5921, Acc : 0.421875, Loss : 1.0835
# Validation Iter : 5921, Acc : 0.375, Loss : 1.0979
# Training Iter : 5922, Acc : 0.390625, Loss : 1.0494
# Training Iter : 5923, Acc : 0.390625, Loss : 1.0964
# Training Iter : 5924, Acc : 0.296875, Loss : 1.1261
# Training Iter : 5925, Acc : 0.3125, Loss : 1.0814
# Training Iter : 5926, Acc : 0.421875, Loss : 1.0560
# Training Iter : 5927, Acc : 0.328125, Loss : 1.0730
# Training Iter : 5928, Acc : 0.5, Loss : 1.0565
# Training Iter : 5929, Acc : 0.5, Loss : 1.0482
# Training Iter : 5930, Acc : 0.375, Loss : 1.0439
# Training Iter : 5931, Acc : 0.421875, Loss : 1.0310
# Validation Iter : 5931, Acc : 0.328125, Loss : 1.1459
# Training Iter : 5932, Acc : 0.390625, Loss : 1.0243
# Training Iter : 5933, Acc : 0.421875, Loss : 1.0324
# Training Iter : 5934, Acc : 0.328125, Loss : 1.0909
# Training Iter : 5935, Acc : 0.28125, Loss : 1.0822
# Training Iter : 5936, Acc : 0.5, Loss : 1.0712
# Training Iter : 5937, Acc : 0.375, Loss : 1.1009
# Training Iter : 5938, Acc : 0.4375, Loss : 1.0722
# Training Iter : 5939, Acc : 0.375, Loss : 1.1071
# Training Iter : 5940, Acc : 0.40625, Loss : 1.0442
# Training Iter : 5941, Acc : 0.3125, Loss : 1.1446
# Validation Iter : 5941, Acc : 0.265625, Loss : 1.1578
# Training Iter : 5942, Acc : 0.375, Loss : 1.1036
# Training Iter : 5943, Acc : 0.359375, Loss : 1.0822
# Training Iter : 5944, Acc : 0.34375, Loss : 1.0997
# Training Iter : 5945, Acc : 0.34375, Loss : 1.1178
# Training Iter : 5946, Acc : 0.21875, Loss : 1.1402
# Training Iter : 5947, Acc : 0.421875, Loss : 1.0882
# Training Iter : 5948, Acc : 0.34375, Loss : 1.0836
# Training Iter : 5949, Acc : 0.375, Loss : 1.1229
# Training Iter : 5950, Acc : 0.375, Loss : 1.1144
# Training Iter : 5951, Acc : 0.28125, Loss : 1.0994
# Validation Iter : 5951, Acc : 0.3125, Loss : 1.1190
# Training Iter : 5952, Acc : 0.484375, Loss : 1.0741
# Training Iter : 5953, Acc : 0.359375, Loss : 1.1160
# Training Iter : 5954, Acc : 0.390625, Loss : 1.1008
# Training Iter : 5955, Acc : 0.390625, Loss : 1.0890
# Training Iter : 5956, Acc : 0.421875, Loss : 1.0679
# Training Iter : 5957, Acc : 0.296875, Loss : 1.1061
# Training Iter : 5958, Acc : 0.453125, Loss : 1.0788
# Training Iter : 5959, Acc : 0.46875, Loss : 1.0768
# Training Iter : 5960, Acc : 0.390625, Loss : 1.0741
# Training Iter : 5961, Acc : 0.421875, Loss : 1.0598
# Validation Iter : 5961, Acc : 0.359375, Loss : 1.1285
# Training Iter : 5962, Acc : 0.359375, Loss : 1.0565
# Training Iter : 5963, Acc : 0.28125, Loss : 1.1375
# Training Iter : 5964, Acc : 0.28125, Loss : 1.1357
# Training Iter : 5965, Acc : 0.4375, Loss : 1.0992
# Training Iter : 5966, Acc : 0.546875, Loss : 1.0404
# Training Iter : 5967, Acc : 0.4375, Loss : 1.0574
# Training Iter : 5968, Acc : 0.40625, Loss : 1.0880
# Training Iter : 5969, Acc : 0.484375, Loss : 1.0686
# Training Iter : 5970, Acc : 0.375, Loss : 1.0832
# Training Iter : 5971, Acc : 0.421875, Loss : 1.1093
# Validation Iter : 5971, Acc : 0.265625, Loss : 1.1586
# Training Iter : 5972, Acc : 0.375, Loss : 1.0965
# Training Iter : 5973, Acc : 0.453125, Loss : 1.0520
# Training Iter : 5974, Acc : 0.453125, Loss : 1.1518
# Training Iter : 5975, Acc : 0.453125, Loss : 1.0313
# Training Iter : 5976, Acc : 0.421875, Loss : 1.0600
# Training Iter : 5977, Acc : 0.40625, Loss : 1.0635
# Training Iter : 5978, Acc : 0.515625, Loss : 1.0082
# Training Iter : 5979, Acc : 0.3125, Loss : 1.1676
# Training Iter : 5980, Acc : 0.375, Loss : 1.1169
# Training Iter : 5981, Acc : 0.484375, Loss : 1.0477
# Validation Iter : 5981, Acc : 0.328125, Loss : 1.1250
# Training Iter : 5982, Acc : 0.40625, Loss : 1.0653
# Training Iter : 5983, Acc : 0.5625, Loss : 1.0330
# Training Iter : 5984, Acc : 0.46875, Loss : 1.0348
# Training Iter : 5985, Acc : 0.359375, Loss : 1.0882
# Training Iter : 5986, Acc : 0.328125, Loss : 1.1141
# Training Iter : 5987, Acc : 0.21875, Loss : 1.1840
# Training Iter : 5988, Acc : 0.34375, Loss : 1.1122
# Training Iter : 5989, Acc : 0.296875, Loss : 1.1077
# Training Iter : 5990, Acc : 0.515625, Loss : 1.0877
# Training Iter : 5991, Acc : 0.515625, Loss : 1.0888
# Validation Iter : 5991, Acc : 0.390625, Loss : 1.1063
# Training Iter : 5992, Acc : 0.453125, Loss : 1.0741
# Training Iter : 5993, Acc : 0.59375, Loss : 1.0440
# Training Iter : 5994, Acc : 0.484375, Loss : 1.0801
# Training Iter : 5995, Acc : 0.5, Loss : 1.0585
# Training Iter : 5996, Acc : 0.5, Loss : 1.0783
# Training Iter : 5997, Acc : 0.578125, Loss : 1.0278
# Training Iter : 5998, Acc : 0.578125, Loss : 1.0040
# Training Iter : 5999, Acc : 0.28125, Loss : 1.1453
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-1476ccefc8fe> in <module>()
#       8         for j in range(train_batches):
#       9             summary, _, acc, loss_ = sess.run([model.merged_summary_op, optimizer, model.accuracy, model.loss],
# ---> 10                                               feed_dict={handle: train_handle, model.learning_rate: LEARNING_RATE})
#      11             step = tf.train.global_step(sess, model.global_step)
#      12             print("Training Iter : {}, Acc : {}, Loss : {:.4f}".format(step, acc, loss_))
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
train_batches
# Out:
# 8533

# %%
end_time = time.time() - start_time
print("{} seconds".format(end_time))

saver.save(sess, os.path.join(logs_path, 'VGG16_classification_crop', model_name))
# Out:
# 3277.8827085494995 seconds
# './input_data\\graph\\VGG16_classification_crop\\vgg16_classification_crop10'

# %%
sess.run(infer_iterator.initializer)
y_true, y_pred = sess.run([model.y, model.y_pred], feed_dict={handle:infer_handle})
i = 0

while True:
    try:
        tmp_true, tmp_pred = sess.run([model.y, model.y_pred], feed_dict={handle:infer_handle})
        y_true = np.concatenate((y_true, tmp_true))
        y_pred = np.concatenate((y_pred, tmp_pred))
        if i % 200 == 0:
            print(i)
        i += 1
    except:
        y_true = np.array([np.where(r==1)[0][0] for r in y_true])
        break
# Out:
# 0
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000

# %%
len(np.repeat(label[ts_idx], 10))
# label[ts_idx]
# Out:
# 128690

# %%
len(label)
# Out:
# 64346

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 0, 0, 0], dtype=int64)

# %%
df2 = pd.DataFrame(data={'y_true':y_true, 'y_pred':y_pred} )
df2.to_csv("true_and_pred.csv", encoding='utf-8', index=False)

# %%
sess.run(infer_iterator.initializer)
y_true, y_pred, y_prob = sess.run([model.y, model.y_pred, model.y_prob], feed_dict={handle:infer_handle})
i = 0

while True:
    try:
        tmp_true, tmp_pred, tmp_prob = sess.run([model.y, model.y_pred, model.y_prob], feed_dict={handle:infer_handle})
        y_true = np.concatenate((y_true, tmp_true))
        y_pred = np.concatenate((y_pred, tmp_pred))
        y_prob = np.concatenate((y_prob, tmp_prob))
        if i % 200 == 0:
            print(i)
        i += 1
    except:
        y_true = np.array([np.where(r==1)[0][0] for r in y_true])
        break

def report_to_df(y_true, y_pred, y_prob):
    cm = skm.confusion_matrix(y_true, y_pred)
    acc = skm.accuracy_score(y_true, y_pred)  # Accuracy
    print("Accuracy : {}".format(acc))
    pd.DataFrame(cm).to_csv("{}_cm.csv".format(model_name), encoding='utf-8')
    
    report = skm.precision_recall_fscore_support(y_true, y_pred)
    out_dict = {
                 "precision" :report[0].round(2)
                ,"recall" : report[1].round(2)
                ,"f1-score" : report[2].round(2)
                ,"support" : report[3]
                }
    out_df = pd.DataFrame(out_dict)
    avg_total = (out_df.apply(lambda x: round(x.mean(), 2) if x.name!="support" else  round(x.sum(), 2)).to_frame().T)
    avg_total.index = ["avg/total"]
    out_df = out_df.append(avg_tot)
    auroc = list()
    for i in range(NUM_CLASSES):
        fpr, tpr, thresholds =skm.roc_curve(y_true, y_prob[:,i], pos_label=i)
        auc = skm.auc(fpr, tpr)
        auroc.append(auc)
    auroc.append(np.mean(auroc))
    auroc_df= pd.DataFrame(auroc, columns=["AUROC"]).set_index([[0,1,2,'avg/total']])
    
    df = pd.concat([out_df, auroc_df], axis=1)
    df.to_csv("{}_report.csv".format(model_name), encoding='utf-8')
    
report_to_df(y_true, y_pred, y_prob)

# %%
report_to_df(y_true, y_pred, y_prob)
